# %% [markdown]
# # Dataset Description: E-commerce Customer Behavior

# %% [markdown]
# ### Overview:
# This dataset provides a comprehensive view of customer behavior within an e-commerce platform. Each entry in the dataset corresponds to a unique customer, offering a detailed breakdown of their interactions and transactions. The information is crafted to facilitate a nuanced analysis of customer preferences, engagement patterns, and satisfaction levels, aiding businesses in making data-driven decisions to enhance the customer experience.

# %% [markdown]
# # Columns:
#
# * Customer ID:
# Type: Numeric
# Description: A unique identifier assigned to each customer, ensuring distinction across the dataset.
#
# * Gender:
# Type: Categorical (Male, Female)
# Description: Specifies the gender of the customer, allowing for gender-based analytics.
#
# * Age:
# Type: Numeric
# Description: Represents the age of the customer, enabling age-group-specific insights.
#
# * City:
# Type: Categorical (City names)
# Description: Indicates the city of residence for each customer, providing geographic insights.
#
# * Membership Type:
# Type: Categorical (Gold, Silver, Bronze)
# Description: Identifies the type of membership held by the customer, influencing perks and benefits.
#
# * Total Spend:
# Type: Numeric
# Description: Records the total monetary expenditure by the customer on the e-commerce platform.
#
# * Items Purchased:
# Type: Numeric
# Description: Quantifies the total number of items purchased by the customer.
#
# * Average Rating:
# Type: Numeric (0 to 5, with decimals)
# Description: Represents the average rating given by the customer for purchased items, gauging satisfaction.
#
# * Discount Applied:
# Type: Boolean (True, False)
# Description: Indicates whether a discount was applied to the customer's purchase, influencing buying behavior.
#
# * Days Since Last Purchase:
# Type: Numeric
# Description: Reflects the number of days elapsed since the customer's most recent purchase, aiding in retention analysis.
#
# * Satisfaction Level:
# Type: Categorical (Satisfied, Neutral, Unsatisfied)
# Description: Captures the overall satisfaction level of the customer, providing a subjective measure of their experience.

# %% [markdown]
# ### Step 1: Importing Necessary Libraries

# %%
## import important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: Load the Dataset

# %%
customer_data=pd.read_csv("E-commerce Customer Behavior.csv")

# %%
customer_data
# Out:
#      Customer ID  Gender  Age           City Membership Type  Total Spend  \
# 0            101  Female   29       New York            Gold      1120.20
# 1            102    Male   34    Los Angeles          Silver       780.50
# 2            103  Female   43        Chicago          Bronze       510.75
# 3            104    Male   30  San Francisco            Gold      1480.30
# 4            105    Male   27          Miami          Silver       720.40
# ..           ...     ...  ...            ...             ...          ...
# 345          446    Male   32          Miami          Silver       660.30
# 346          447  Female   36        Houston          Bronze       470.50
# 347          448  Female   30       New York            Gold      1190.80
# 348          449    Male   34    Los Angeles          Silver       780.20
# 349          450  Female   43        Chicago          Bronze       515.75
#
#      Items Purchased  Average Rating  Discount Applied  \
# ...

# %% [markdown]
# ### Step 3: Explore customer_data

# %%
customer_data.describe()
# Out:
#        Customer ID         Age  Total Spend  Items Purchased  Average Rating  \
# count   350.000000  350.000000   350.000000       350.000000      350.000000
# mean    275.500000   33.597143   845.381714        12.600000        4.019143
# std     101.180532    4.870882   362.058695         4.155984        0.580539
# min     101.000000   26.000000   410.800000         7.000000        3.000000
# 25%     188.250000   30.000000   502.000000         9.000000        3.500000
# 50%     275.500000   32.500000   775.200000        12.000000        4.100000
# 75%     362.750000   37.000000  1160.600000        15.000000        4.500000
# max     450.000000   43.000000  1520.100000        21.000000        4.900000
#
#        Days Since Last Purchase
# count                350.000000
# mean                  26.588571
# std                   13.440813
# min                    9.000000
# 25%                   15.000000
# 50%                   23.000000
# 75%                   38.000000
# ...

# %%
## if i want to describe only int data type
int_describe=customer_data.select_dtypes(include='int')
int_describe.describe()
# Out:
#        Customer ID         Age  Items Purchased  Days Since Last Purchase
# count   350.000000  350.000000       350.000000                350.000000
# mean    275.500000   33.597143        12.600000                 26.588571
# std     101.180532    4.870882         4.155984                 13.440813
# min     101.000000   26.000000         7.000000                  9.000000
# 25%     188.250000   30.000000         9.000000                 15.000000
# 50%     275.500000   32.500000        12.000000                 23.000000
# 75%     362.750000   37.000000        15.000000                 38.000000
# max     450.000000   43.000000        21.000000                 63.000000

# %%
## if i want to describe only object data type
object_describe=customer_data.select_dtypes(include='object')
object_describe.describe()
# Out:
#         Gender      City Membership Type Satisfaction Level
# count      350       350             350                348
# unique       2         6               3                  3
# top     Female  New York            Gold          Satisfied
# freq       175        59             117                125

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               350 non-null    int64
#  1   Gender                    350 non-null    object
#  2   Age                       350 non-null    int64
#  3   City                      350 non-null    object
#  4   Membership Type           350 non-null    object
#  5   Total Spend               350 non-null    float64
#  6   Items Purchased           350 non-null    int64
#  7   Average Rating            350 non-null    float64
#  8   Discount Applied          350 non-null    bool
#  9   Days Since Last Purchase  350 non-null    int64
#  10  Satisfaction Level        348 non-null    object
# dtypes: bool(1), float64(2), int64(4), object(4)
# memory usage: 27.8+ KB

# %%
customer_data.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'City', 'Membership Type',
#        'Total Spend', 'Items Purchased', 'Average Rating', 'Discount Applied',
#        'Days Since Last Purchase', 'Satisfaction Level'],
#       dtype='object')

# %% [markdown]
# ### Rename column name:-

# %%
customer_data.rename(columns={"Customer ID":"ID"}, inplace=True)

# %%
customer_data.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'City', 'Membership Type', 'Total Spend',
#        'Items Purchased', 'Average Rating', 'Discount Applied',
#        'Days Since Last Purchase', 'Satisfaction Level'],
#       dtype='object')

# %%
rename_columns=({"Membership Type":"Membership_Type",
                 "Total Spend":"Total_Spend",
                 "Items Purchased":"Items_Purchased",
                 "Average Rating":"Average_Rating",
                 "Discount Applied":"Discount_Applied",
                  "Days Since Last Purchase":"Days_Since_Last_Purchase",
                 "Satisfaction Level":"Satisfaction_Level"
})

# %%
customer_data.rename(columns=rename_columns, inplace=True)

# %%
customer_data.columns
# Out:
# Index(['ID', 'Gender', 'Age', 'City', 'Membership_Type', 'Total_Spend',
#        'Items_Purchased', 'Average_Rating', 'Discount_Applied',
#        'Days_Since_Last_Purchase', 'Satisfaction_Level'],
#       dtype='object')

# %%
customer_data
# Out:
#       ID  Gender  Age           City Membership_Type  Total_Spend  \
# 0    101  Female   29       New York            Gold      1120.20
# 1    102    Male   34    Los Angeles          Silver       780.50
# 2    103  Female   43        Chicago          Bronze       510.75
# 3    104    Male   30  San Francisco            Gold      1480.30
# 4    105    Male   27          Miami          Silver       720.40
# ..   ...     ...  ...            ...             ...          ...
# 345  446    Male   32          Miami          Silver       660.30
# 346  447  Female   36        Houston          Bronze       470.50
# 347  448  Female   30       New York            Gold      1190.80
# 348  449    Male   34    Los Angeles          Silver       780.20
# 349  450  Female   43        Chicago          Bronze       515.75
#
#      Items_Purchased  Average_Rating  Discount_Applied  \
# 0                 14             4.6              True
# 1                 11             4.1             False
# ...

# %% [markdown]
# ### Data Distribution :-

# %%
customer_data["Gender"].value_counts()
# Out:
# Female    175
# Male      175
# Name: Gender, dtype: int64

# %%
customer_data["City"].value_counts()
# Out:
# New York         59
# Los Angeles      59
# Chicago          58
# San Francisco    58
# Miami            58
# Houston          58
# Name: City, dtype: int64

# %%
customer_data["Membership_Type"].value_counts()
# Out:
# Gold      117
# Silver    117
# Bronze    116
# Name: Membership_Type, dtype: int64

# %%
customer_data["Discount_Applied"].value_counts()
# Out:
# True     175
# False    175
# Name: Discount_Applied, dtype: int64

# %%
customer_data["Satisfaction_Level"].value_counts()
# Out:
# Satisfied      125
# Unsatisfied    116
# Neutral        107
# Name: Satisfaction_Level, dtype: int64

# %% [markdown]
# ### Step 4:-Exploratory Data Analysis(EDA):-

# %% [markdown]
# ### 1.Univariate Analysis:

# %%
import sweetviz as sv
a=sv.analyze(customer_data)
a.show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ### Univariate analysis using histogram

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,6),facecolor="pink")
sns.histplot(customer_data['Satisfaction_Level'])
plt.xlabel('Satisfaction_Level',fontsize=20)
plt.ylabel('count',fontsize=25)
plt.title('Histogram of Satisfaction_Level columns',fontsize=20)
plt.tight_layout()
plt.show()

# %%
sns.histplot(customer_data['Satisfaction_Level'])
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,20),facecolor="pink")
plotnumber=1
for i in customer_data:
    ax=plt.subplot(5,5,plotnumber)
    sns.histplot(customer_data[i])
    plt.xlabel(i,fontsize=20)
    plt.ylabel('count',fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %% [markdown]
# ### Univariate Analysis using countplot

# %%
sns.countplot(x='Gender',hue='Satisfaction_Level',data=customer_data)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(40,40),facecolor="pink")
plotnumber=1
for i in customer_data.columns:
    ax=plt.subplot(5,5,plotnumber)
    sns.countplot(x=i,hue='Satisfaction_Level', data=customer_data)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2. Bivariate Analysis using Autoviz

# %%
pip install autoviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# AutoViz visualization with all available charts
AV = AutoViz_Class()
report = AV.AutoViz(
    filename='',
    dfte=customer_data,
    max_cols_analyzed=30,
    depVar='Churn'  # Specify the target variable if needed
)
# Out:
# Shape of your Data Set loaded: (350, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  5
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  4
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     12 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['ID']
# ...

# %% [markdown]
# # Data Preprocessing:-

# %% [markdown]
# ### step1:- Handle Null value

# %%
customer_data.isnull().sum()
# Out:
# ID                          0
# Gender                      0
# Age                         0
# City                        0
# Membership_Type             0
# Total_Spend                 0
# Items_Purchased             0
# Average_Rating              0
# Discount_Applied            0
# Days_Since_Last_Purchase    0
# Satisfaction_Level          2
# dtype: int64

# %%
customer_data['Satisfaction_Level'].mode()
# Out:
# 0    Satisfied
# Name: Satisfaction_Level, dtype: object

# %%
customer_data.loc[customer_data['Satisfaction_Level'].isnull()==True,'Satisfaction_Level']='Satisfied'

# %%
customer_data['Satisfaction_Level'].value_counts()
# Out:
# Satisfied      127
# Unsatisfied    116
# Neutral        107
# Name: Satisfaction_Level, dtype: int64

# %% [markdown]
# ### Step2:- Handle Categorical Data:-

# %%
customer_data
# Out:
#       ID  Gender  Age           City Membership_Type  Total_Spend  \
# 0    101  Female   29       New York            Gold      1120.20
# 1    102    Male   34    Los Angeles          Silver       780.50
# 2    103  Female   43        Chicago          Bronze       510.75
# 3    104    Male   30  San Francisco            Gold      1480.30
# 4    105    Male   27          Miami          Silver       720.40
# ..   ...     ...  ...            ...             ...          ...
# 345  446    Male   32          Miami          Silver       660.30
# 346  447  Female   36        Houston          Bronze       470.50
# 347  448  Female   30       New York            Gold      1190.80
# 348  449    Male   34    Los Angeles          Silver       780.20
# 349  450  Female   43        Chicago          Bronze       515.75
#
#      Items_Purchased  Average_Rating  Discount_Applied  \
# 0                 14             4.6              True
# 1                 11             4.1             False
# ...

# %% [markdown]
# ### Label encoding:-

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
customer_data['Gender']=lb.fit_transform(customer_data['Gender'])

# %%
customer_data
# Out:
#       ID  Gender  Age           City Membership_Type  Total_Spend  \
# 0    101       0   29       New York            Gold      1120.20
# 1    102       1   34    Los Angeles          Silver       780.50
# 2    103       0   43        Chicago          Bronze       510.75
# 3    104       1   30  San Francisco            Gold      1480.30
# 4    105       1   27          Miami          Silver       720.40
# ..   ...     ...  ...            ...             ...          ...
# 345  446       1   32          Miami          Silver       660.30
# 346  447       0   36        Houston          Bronze       470.50
# 347  448       0   30       New York            Gold      1190.80
# 348  449       1   34    Los Angeles          Silver       780.20
# 349  450       0   43        Chicago          Bronze       515.75
#
#      Items_Purchased  Average_Rating  Discount_Applied  \
# 0                 14             4.6              True
# 1                 11             4.1             False
# ...

# %%
customer_data['Discount_Applied']=lb.fit_transform(customer_data['Discount_Applied'])

# %%
customer_data['Satisfaction_Level']=lb.fit_transform(customer_data['Satisfaction_Level'])

# %% [markdown]
# ### Manual encoding

# %%
customer_data['City'].value_counts()
# Out:
# New York         59
# Los Angeles      59
# Chicago          58
# San Francisco    58
# Miami            58
# Houston          58
# Name: City, dtype: int64

# %%
customer_data['City']=customer_data['City'].map({'New York':0,'Los Angeles':1,'Chicago':2,'San Francisco':3,'Miami':4,'Houston':5 })

# %%
customer_data
# Out:
#       ID  Gender  Age  City Membership_Type  Total_Spend  Items_Purchased  \
# 0    101       0   29     0            Gold      1120.20               14
# 1    102       1   34     1          Silver       780.50               11
# 2    103       0   43     2          Bronze       510.75                9
# 3    104       1   30     3            Gold      1480.30               19
# 4    105       1   27     4          Silver       720.40               13
# ..   ...     ...  ...   ...             ...          ...              ...
# 345  446       1   32     4          Silver       660.30               10
# 346  447       0   36     5          Bronze       470.50                8
# 347  448       0   30     0            Gold      1190.80               16
# 348  449       1   34     1          Silver       780.20               11
# 349  450       0   43     2          Bronze       515.75               10
#
#      Average_Rating  Discount_Applied  Days_Since_Last_Purchase  \
# ...

# %% [markdown]
# ### One Hot Encoding:-

# %%
data=pd.get_dummies(customer_data['Membership_Type'],prefix='Membership_Type',drop_first=True)

# %%
data
# Out:
#      Membership_Type_Gold  Membership_Type_Silver
# 0                       1                       0
# 1                       0                       1
# 2                       0                       0
# 3                       1                       0
# 4                       0                       1
# ..                    ...                     ...
# 345                     0                       1
# 346                     0                       0
# 347                     1                       0
# 348                     0                       1
# 349                     0                       0
#
# [350 rows x 2 columns]

# %%
customer_data['Membership_Type'].value_counts()
# Out:
# Gold      117
# Silver    117
# Bronze    116
# Name: Membership_Type, dtype: int64

# %%
customer_data=pd.concat([customer_data,data],axis=1)

# %%
customer_data
# Out:
#       ID  Gender  Age  City Membership_Type  Total_Spend  Items_Purchased  \
# 0    101       0   29     0            Gold      1120.20               14
# 1    102       1   34     1          Silver       780.50               11
# 2    103       0   43     2          Bronze       510.75                9
# 3    104       1   30     3            Gold      1480.30               19
# 4    105       1   27     4          Silver       720.40               13
# ..   ...     ...  ...   ...             ...          ...              ...
# 345  446       1   32     4          Silver       660.30               10
# 346  447       0   36     5          Bronze       470.50                8
# 347  448       0   30     0            Gold      1190.80               16
# 348  449       1   34     1          Silver       780.20               11
# 349  450       0   43     2          Bronze       515.75               10
#
#      Average_Rating  Discount_Applied  Days_Since_Last_Purchase  \
# ...

# %%
customer_data.drop(columns=['Membership_Type'],inplace=True)

# %%
customer_data
# Out:
#       ID  Gender  Age  City  Total_Spend  Items_Purchased  Average_Rating  \
# 0    101       0   29     0      1120.20               14             4.6
# 1    102       1   34     1       780.50               11             4.1
# 2    103       0   43     2       510.75                9             3.4
# 3    104       1   30     3      1480.30               19             4.7
# 4    105       1   27     4       720.40               13             4.0
# ..   ...     ...  ...   ...          ...              ...             ...
# 345  446       1   32     4       660.30               10             3.8
# 346  447       0   36     5       470.50                8             3.0
# 347  448       0   30     0      1190.80               16             4.5
# 348  449       1   34     1       780.20               11             4.2
# 349  450       0   43     2       515.75               10             3.3
#
#      Discount_Applied  Days_Since_Last_Purchase  Satisfaction_Level  \
# ...

# %% [markdown]
# ### step3:- Handle Outlier:-

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.figure(figsize=(15,20),facecolor='pink')
plotnumber=1
for i in customer_data:
    if plotnumber<=13:
        
        plt.subplot(5,3,plotnumber)
        sns.boxplot(customer_data[i])
        plt.xlabel(i,fontsize=20)
        plt.ylabel('Satisfaction_Level',fontsize=20)
    plotnumber+=1
plt.tight_layout
plt.show()

# %% [markdown]
# ### Remove Unnecessory Columns:-

# %%
customer_data=customer_data.drop(columns=['ID'])

# %%
customer_data
# Out:
#      Gender  Age  City  Total_Spend  Items_Purchased  Average_Rating  \
# 0         0   29     0      1120.20               14             4.6
# 1         1   34     1       780.50               11             4.1
# 2         0   43     2       510.75                9             3.4
# 3         1   30     3      1480.30               19             4.7
# 4         1   27     4       720.40               13             4.0
# ..      ...  ...   ...          ...              ...             ...
# 345       1   32     4       660.30               10             3.8
# 346       0   36     5       470.50                8             3.0
# 347       0   30     0      1190.80               16             4.5
# 348       1   34     1       780.20               11             4.2
# 349       0   43     2       515.75               10             3.3
#
#      Discount_Applied  Days_Since_Last_Purchase  Satisfaction_Level  \
# 0                   1                        25                   1
# ...

# %%
customer_data['Membership_Type_Silver'].value_counts()
# Out:
# 0    233
# 1    117
# Name: Membership_Type_Silver, dtype: int64

# %% [markdown]
# ###  step 4:-Scalling:-

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
numerical_columns=customer_data[['Age','City','Total_Spend','Items_Purchased','Average_Rating','Days_Since_Last_Purchase']]
scalled_data=sc.fit_transform(numerical_columns)
scalled_data
# Out:
# array([[0.17647059, 0.        , 0.63950239, 0.5       , 0.84210526,
#         0.2962963 ],
#        [0.47058824, 0.2       , 0.33327324, 0.28571429, 0.57894737,
#         0.16666667],
#        [1.        , 0.4       , 0.09010187, 0.14285714, 0.21052632,
#         0.61111111],
#        ...,
#        [0.23529412, 0.        , 0.70314613, 0.64285714, 0.78947368,
#         0.35185185],
#        [0.47058824, 0.2       , 0.33300279, 0.28571429, 0.63157895,
#         0.22222222],
#        [1.        , 0.4       , 0.09460921, 0.21428571, 0.15789474,
#         0.74074074]])

# %%
numerical_columns
# Out:
#      Age  City  Total_Spend  Items_Purchased  Average_Rating  \
# 0     29     0      1120.20               14             4.6
# 1     34     1       780.50               11             4.1
# 2     43     2       510.75                9             3.4
# 3     30     3      1480.30               19             4.7
# 4     27     4       720.40               13             4.0
# ..   ...   ...          ...              ...             ...
# 345   32     4       660.30               10             3.8
# 346   36     5       470.50                8             3.0
# 347   30     0      1190.80               16             4.5
# 348   34     1       780.20               11             4.2
# 349   43     2       515.75               10             3.3
#
#      Days_Since_Last_Purchase
# 0                          25
# 1                          18
# 2                          42
# 3                          12
# 4                          55
# ..                        ...
# ...

# %%
df2 = pd.DataFrame(scalled_data, columns=['Age','City','Total_Spend','Items_Purchased','Average_Rating','Days_Since_Last_Purchase'])
df2
# Out:
#           Age  City  Total_Spend  Items_Purchased  Average_Rating  \
# 0    0.176471   0.0     0.639502         0.500000        0.842105
# 1    0.470588   0.2     0.333273         0.285714        0.578947
# 2    1.000000   0.4     0.090102         0.142857        0.210526
# 3    0.235294   0.6     0.964122         0.857143        0.894737
# 4    0.058824   0.8     0.279095         0.428571        0.526316
# ..        ...   ...          ...              ...             ...
# 345  0.352941   0.8     0.224917         0.214286        0.421053
# 346  0.588235   1.0     0.053818         0.071429        0.000000
# 347  0.235294   0.0     0.703146         0.642857        0.789474
# 348  0.470588   0.2     0.333003         0.285714        0.631579
# 349  1.000000   0.4     0.094609         0.214286        0.157895
#
#      Days_Since_Last_Purchase
# 0                    0.296296
# 1                    0.166667
# 2                    0.611111
# 3                    0.055556
# ...

# %% [markdown]
# ### step 5:- Correlation

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %%
data=df2.drop(columns=['Items_Purchased','Average_Rating'])

# %%
data
# Out:
#           Age  City  Total_Spend  Days_Since_Last_Purchase
# 0    0.176471   0.0     0.639502                  0.296296
# 1    0.470588   0.2     0.333273                  0.166667
# 2    1.000000   0.4     0.090102                  0.611111
# 3    0.235294   0.6     0.964122                  0.055556
# 4    0.058824   0.8     0.279095                  0.851852
# ..        ...   ...          ...                       ...
# 345  0.352941   0.8     0.224917                  0.611111
# 346  0.588235   1.0     0.053818                  0.333333
# 347  0.235294   0.0     0.703146                  0.351852
# 348  0.470588   0.2     0.333003                  0.222222
# 349  1.000000   0.4     0.094609                  0.740741
#
# [350 rows x 4 columns]

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
final_data=pd.concat([data,customer_data[['Gender','Discount_Applied','Satisfaction_Level','Membership_Type_Gold','Membership_Type_Silver']]],axis=1)

# %%
customer_data
# Out:
#      Gender  Age  City  Total_Spend  Items_Purchased  Average_Rating  \
# 0         0   29     0      1120.20               14             4.6
# 1         1   34     1       780.50               11             4.1
# 2         0   43     2       510.75                9             3.4
# 3         1   30     3      1480.30               19             4.7
# 4         1   27     4       720.40               13             4.0
# ..      ...  ...   ...          ...              ...             ...
# 345       1   32     4       660.30               10             3.8
# 346       0   36     5       470.50                8             3.0
# 347       0   30     0      1190.80               16             4.5
# 348       1   34     1       780.20               11             4.2
# 349       0   43     2       515.75               10             3.3
#
#      Discount_Applied  Days_Since_Last_Purchase  Satisfaction_Level  \
# 0                   1                        25                   1
# ...

# %%
final_data
# Out:
#           Age  City  Total_Spend  Days_Since_Last_Purchase  Gender  \
# 0    0.176471   0.0     0.639502                  0.296296       0
# 1    0.470588   0.2     0.333273                  0.166667       1
# 2    1.000000   0.4     0.090102                  0.611111       0
# 3    0.235294   0.6     0.964122                  0.055556       1
# 4    0.058824   0.8     0.279095                  0.851852       1
# ..        ...   ...          ...                       ...     ...
# 345  0.352941   0.8     0.224917                  0.611111       1
# 346  0.588235   1.0     0.053818                  0.333333       0
# 347  0.235294   0.0     0.703146                  0.351852       0
# 348  0.470588   0.2     0.333003                  0.222222       1
# 349  1.000000   0.4     0.094609                  0.740741       0
#
#      Discount_Applied  Satisfaction_Level  Membership_Type_Gold  \
# 0                   1                   1                     1
# ...

# %% [markdown]
# ### step6:-  Model Creation:-

# %%
x=final_data.drop(columns='Satisfaction_Level')

# %%
x
# Out:
#           Age  City  Total_Spend  Days_Since_Last_Purchase  Gender  \
# 0    0.176471   0.0     0.639502                  0.296296       0
# 1    0.470588   0.2     0.333273                  0.166667       1
# 2    1.000000   0.4     0.090102                  0.611111       0
# 3    0.235294   0.6     0.964122                  0.055556       1
# 4    0.058824   0.8     0.279095                  0.851852       1
# ..        ...   ...          ...                       ...     ...
# 345  0.352941   0.8     0.224917                  0.611111       1
# 346  0.588235   1.0     0.053818                  0.333333       0
# 347  0.235294   0.0     0.703146                  0.351852       0
# 348  0.470588   0.2     0.333003                  0.222222       1
# 349  1.000000   0.4     0.094609                  0.740741       0
#
#      Discount_Applied  Membership_Type_Gold  Membership_Type_Silver
# 0                   1                     1                       0
# ...

# %%
y=final_data['Satisfaction_Level']

# %%
y
# Out:
# 0      1
# 1      0
# 2      2
# 3      1
# 4      2
#       ..
# 345    2
# 346    0
# 347    1
# 348    0
# 349    2
# Name: Satisfaction_Level, Length: 350, dtype: int32

# %%
final_data['Satisfaction_Level'].value_counts()
# Out:
# 1    127
# 2    116
# 0    107
# Name: Satisfaction_Level, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test=train_test_split(x,y,test_size=0.2, random_state=45)

# %%
y_train.value_counts()
# Out:
# 1    98
# 2    93
# 0    89
# Name: Satisfaction_Level, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE()
x_train_smote, y_train_smote=smote.fit_resample(x_train,y_train)

# %%
y_train_smote.value_counts()
# Out:
# 0    98
# 2    98
# 1    98
# Name: Satisfaction_Level, dtype: int64

# %% [markdown]
# ###  step7:- Applying Models:-

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=100,random_state=42)
rfc.fit(x_train_smote,y_train_smote)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ### step8:- Make prediction and Evalute:-

# %%
y_pred=rfc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,confusion_matrix,classification_report

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 1.0

# %%
Classification_report=classification_report(y_test,y_pred )

# %%
print(Classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      1.00      1.00        29
#            2       1.00      1.00      1.00        23
#
#     accuracy                           1.00        70
#    macro avg       1.00      1.00      1.00        70
# weighted avg       1.00      1.00      1.00        70

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
conf_matrix
# Out:
# array([[18,  0,  0],
#        [ 0, 29,  0],
#        [ 0,  0, 23]], dtype=int64)

# %% [markdown]
# ### Feature Importance

# %%
feature_importances = pd.Series(rfc.feature_importances_, index=x.columns)
feature_importances = feature_importances.sort_values(ascending=False)
print('Feature Importances:')
print(feature_importances)
# Out:
# Feature Importances:
# Total_Spend                 0.282141
# Days_Since_Last_Purchase    0.195051
# Discount_Applied            0.166786
# Age                         0.146044
# Membership_Type_Gold        0.097203
# City                        0.093404
# Membership_Type_Silver      0.013724
# Gender                      0.005647
# dtype: float64

# %% [markdown]
# ### Plot Feature Importances

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importances, y=feature_importances.index)
plt.title('Feature Importances')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# ### Output Based On Manual Imputation Of Input Values:-

# %%
import numpy as np

a = eval(input("Enter Age value: "))
b = eval(input("Enter City value: "))
c = eval(input("Enter Total_Spend value: "))
d = eval(input("Enter Days_Since_Last_Purchase value: "))
e = eval(input("Enter Gender value: "))
f = eval(input("Enter Discount_Applied value: "))
g = eval(input("Enter Membership_Type_Gold value: "))
h = eval(input("Enter Membership_Type_Silver value: "))


# Create a numpy array with all 9 values
values = np.array([a, b, c, d, e, f, g, h])

# Assuming xgb2 is your trained XGBoost model
predict = rfc.predict(values.reshape(1, -1))  # Reshape to a 2D array

print("The Satisfaction_Level is:", predict)
# Out:
# Enter Age value: 0.176471
# Enter City value: 0.0
# Enter Total_Spend value: 0.639502
# Enter Days_Since_Last_Purchase value: 0.296296
# Enter Gender value: 0
# Enter Discount_Applied value: 1
# Enter Membership_Type_Gold value: 1
# Enter Membership_Type_Silver value: 0
# The Satisfaction_Level is: [1]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # Conclusion:
# This project successfully analyzed customer behavior in an e-commerce context, built a predictive model for customer satisfaction, and provided actionable insights for business decisions. The high accuracy of the model suggests its potential applicability in real-world scenarios to optimize customer engagement strategies and enhance overall satisfaction levels.

# %% [markdown]
# # Thank you for taking the time to review this project.
# Best regards,
#
# Aarti Valase.
